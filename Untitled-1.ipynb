# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt#to plot accuracy
import cv2
import tensorflow as tf
from PIL import Image
import os
from sklearn.model_selection import train_test_split #to split training and testing data
from keras.utils import to_categorical#to convert the labels present in y_train and t_test into one-hot encoding
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout#to create CNN
from keras.preprocessing.image import ImageDataGenerator  # Import the ImageDataGenerator
from keras.optimizers import Adam as AdamLegacy
from keras.callbacks import LearningRateScheduler

# Define the number of images to load from each class
num_images_per_class = 2000
classes = 43

# Define the directory where your dataset is stored
dataset_dir = "/Users/adityachaturvedi/Desktop/7th Sem/Minor Project"
output_dir = "/Users/adityachaturvedi/Desktop/7th Sem/Minor Project/CleanedData"

# Define the function to clean the data
def clean_data(input_dir, output_dir, num_images_per_class):
    for i in range(classes):
        input_path = os.path.join(input_dir, 'train', str(i))
        output_path = os.path.join(output_dir, 'train', str(i))
        
        if not os.path.exists(output_path):
            os.makedirs(output_path)
        
        images = os.listdir(input_path)[:num_images_per_class]  # Load only a subset of images
        for a in images:
            try:
                image = Image.open(os.path.join(input_path, a))
                image = image.resize((30, 30))
                image.save(os.path.join(output_path, a))
            except:
                print("Error cleaning image:", os.path.join(input_path, a))

# Clean the data
clean_data(dataset_dir, output_dir, num_images_per_class)

def lr_schedule(epoch):
    initial_learning_rate = 0.001
    decay_rate = 0.95
    if epoch >= 10:
        return initial_learning_rate * decay_rate
    return initial_learning_rate

data = []
labels = []
classes = 43
cur_path = os.getcwd()

# Load a smaller subset of images from each class
for i in range(classes):
    path = os.path.join(cur_path, 'train', str(i))
    images = os.listdir(path)[:num_images_per_class]  # Load only a subset of images
    for a in images:
        try:
            image = Image.open(os.path.join(path, a))
            image = image.resize((30, 30))
            image = np.array(image)
            data.append(image)
            labels.append(i)
        except:
            print("Error loading image")


#Converting lists into numpy arrays
data = np.array(data)
labels = np.array(labels)
print(data.shape, labels.shape)

data = data / 255.0

#Splitting training and testing dataset
X_t1, X_t2, y_t1, y_t2 = train_test_split(data, labels, test_size=0.15, random_state=42)
print(X_t1.shape, X_t2.shape, y_t1.shape, y_t2.shape)

# Create a grid of sample images from each class
plt.figure(figsize=(12, 12))
for i in range(43):
    class_indices = np.where(y_t1 == i)[0]
    plt.subplot(7, 7, i + 1)
    plt.imshow(X_t1[class_indices[0]])
    plt.title(f'Class {i}')
    plt.axis('off')
plt.show()


# Data augmentation settings
#Converting the labels into one hot encoding
y_t1 = to_categorical(y_t1, 43)
y_t2 = to_categorical(y_t2, 43)
# Out:
# (38399, 30, 30, 3) (38399,)
# (32639, 30, 30, 3) (5760, 30, 30, 3) (32639,) (5760,)

# %%
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Building the model
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=X_t1.shape[1:]))
model.add(Conv2D(filters=32, kernel_size=(5, 5), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(43, activation='softmax'))

# Compile the model with the Adam optimizer
optimizer = AdamLegacy(learning_rate=0.001)  # Initial learning rate
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])


# Training the model with data augmentation
eps = 30
batch_size = 32

# Define the learning rate scheduler callback
lr_scheduler = LearningRateScheduler(lr_schedule)

# Train the model using augmented data generator with the learning rate scheduler
history = model.fit(
    datagen.flow(X_t1, y_t1, batch_size=batch_size),
    steps_per_epoch=len(X_t1) // batch_size,
    epochs=eps,
    validation_data=(X_t2, y_t2),
    validation_steps=len(X_t2) // batch_size,
    callbacks=[lr_scheduler]
)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
#
29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from keras.models import Model

# Define a model to extract feature maps from intermediate layers
layer_name = 'dropout'  # Replace with the name of the layer you want to visualize
intermediate_layer_model = Model(inputs=model.input, outputs=model.get_layer(layer_name).output)

# Choose an image from the test set for visualization
sample_image = X_t2[0]  # Replace with the index of the image you want to visualize

# Extract feature maps
intermediate_output = intermediate_layer_model.predict(sample_image.reshape(1, 30, 30, 3))

# Plot feature maps
plt.figure(figsize=(12, 6))
for i in range(intermediate_output.shape[-1]):
    plt.subplot(4, 8, i + 1)
    plt.imshow(intermediate_output[0, :, :, i], cmap='viridis')
    plt.axis('off')
plt.suptitle(f'Feature Maps from Layer: {layer_name}')
plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 399 calls to <function Model.make_predict_function.<locals>.predict_function at 0x2cb22aca0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 399 calls to <function Model.make_predict_function.<locals>.predict_function at 0x2cb22aca0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 50ms/step

# %%
# Plotting graphs for accuracy and loss
plt.figure(figsize=(12, 4))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
#plotting graphs for accuracy
plt.figure(0)
plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()
plt.figure(1)
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
#testing accuracy on test dataset
from sklearn.metrics import accuracy_score
y_test = pd.read_csv('Test.csv')
print(y_test)
labels = y_test["ClassId"].values
imgs = y_test["Path"].values
data=[]


# Load and preprocess test data
y_test = pd.read_csv('Test.csv')
labels = y_test["ClassId"].values
imgs = y_test["Path"].values
test_data = []

base_dir = "/Users/adityachaturvedi/Desktop/7th Sem/Minor Project"

for img_path in imgs:
    full_img_path = os.path.join(base_dir, img_path)
    print("Processing image:", full_img_path)  # Print the full image path
    if os.path.exists(full_img_path):
        image = Image.open(full_img_path)
        image = image.resize((30, 30))
        image = np.array(image)
        test_data.append(image)
    else:
        print("Image not found:", full_img_path)  # Print if the image is not found
# Out:
#        Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  ClassId            Path
# 0         53      54       6       5      48      49       16  Test/00000.png
# 1         42      45       5       5      36      40        1  Test/00001.png
# 2         48      52       6       6      43      47       38  Test/00002.png
# 3         27      29       5       5      22      24       33  Test/00003.png
# 4         60      57       5       5      55      52       11  Test/00004.png
# ...      ...     ...     ...     ...     ...     ...      ...             ...
# 12625     42      41       5       6      37      36       12  Test/12625.png
# 12626     50      51       6       5      45      46       33  Test/12626.png
# 12627     29      29       6       6      24      24        6  Test/12627.png
# 12628     48      49       5       6      43      44        7  Test/12628.png
# 12629     32      31       6       5      27      26       10  Test/12629.png
#
# [12630 rows x 8 columns]
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00000.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00001.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00002.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00003.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00004.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00005.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00006.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00007.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00008.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00009.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00010.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00011.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00012.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00013.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00014.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00015.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00016.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00017.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00018.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00019.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00020.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00021.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00022.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00023.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00024.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00025.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00026.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00027.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00028.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00029.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00030.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00031.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00032.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00033.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00034.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00035.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00036.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00037.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00038.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00039.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00040.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00041.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00042.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00043.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00044.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00045.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00046.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00047.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00048.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00049.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00050.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00051.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00052.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00053.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00054.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00055.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00056.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00057.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00058.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00059.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00060.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00061.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00062.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00063.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00064.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00065.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00066.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00067.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00068.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00069.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00070.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00071.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00072.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00073.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00074.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00075.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00076.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00077.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00078.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00079.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00080.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00081.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00082.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00083.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00084.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00085.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00086.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00087.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00088.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00089.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00090.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00091.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00092.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00093.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00094.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00095.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00096.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00097.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00098.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00099.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00100.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00101.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00102.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00103.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00104.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00105.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00106.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00107.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00108.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00109.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00110.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00111.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00112.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00113.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00114.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00115.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00116.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00117.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00118.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00119.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00120.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00121.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00122.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/
png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00520.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00521.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00522.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00523.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00524.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00525.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00526.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00527.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00528.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00529.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00530.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00531.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00532.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00533.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00534.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00535.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00536.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00537.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00538.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/00539.png
# ...
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12447.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12448.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12449.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12450.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12451.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12452.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12453.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12454.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12455.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12456.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12457.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12458.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12459.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12460.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12461.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12462.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12463.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12464.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12465.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12466.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12467.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12468.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12469.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12470.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12471.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12472.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12473.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12474.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12475.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12476.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12477.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12478.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12479.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12480.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12481.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12482.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12483.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12484.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12485.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12486.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12487.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12488.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12489.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12490.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12491.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12492.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12493.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12494.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12495.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12496.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12497.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12498.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12499.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12500.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12501.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12502.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12503.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12504.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12505.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12506.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12507.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12508.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12509.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12510.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12511.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12512.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12513.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12514.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12515.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12516.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12517.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12518.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12519.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12520.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12521.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12522.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12523.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12524.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12525.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12526.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12527.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12528.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12529.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12530.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12531.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12532.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12533.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12534.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12535.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12536.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12537.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12538.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12539.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12540.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12541.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12542.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12543.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12544.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12545.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12546.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12547.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12548.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12549.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12550.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12551.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12552.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12553.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12554.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12555.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12556.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12557.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12558.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12559.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12560.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12561.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12562.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12563.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12564.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12565.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12566.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12567.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12568.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12569.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12570.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12571.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12572.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12573.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12574.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12575.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12576.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12577.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12578.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12579.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12580.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12581.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12582.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12583.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12584.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12585.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12586.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12587.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12588.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12589.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12590.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12591.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12592.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12593.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12594.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12595.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12596.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12597.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12598.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12599.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12600.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12601.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12602.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12603.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12604.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12605.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12606.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12607.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12608.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12609.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12610.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12611.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12612.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12613.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12614.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12615.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12616.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12617.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12618.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12619.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12620.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12621.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12622.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12623.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12624.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12625.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12626.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12627.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12628.png
# Processing image: /Users/adityachaturvedi/Desktop/7th Sem/Minor Project/Test/12629.png

# %%
X_test = np.array(test_data)

# Predictions on test data
pred_probs_test = model.predict(X_test)
predicted_classes_test = pred_probs_test.argmax(axis=-1)

# Calculate accuracy on test data
accuracy_test = accuracy_score(labels, predicted_classes_test)
print("Test accuracy:", accuracy_test)
# Out:
# 395/395 [==============================] - 6s 14ms/step
# Test accuracy: 0.8292161520190023

# %% [markdown]
# In your traffic sign detection project, the confusion matrix is your compass. It's crucial for:
#
# 1. Performance Assessment: It tells you how well your model predicts traffic sign classes.
#
# 2. Error Identification: Shows which signs your model often confuses, helping you focus on improvements.
#
# 3. Precision and Recall: Lets you calculate precision (positive prediction accuracy) and recall (ability to capture all positives) for each class.
#
# With the confusion matrix as your guide, you'll navigate toward an accurate and reliable traffic sign recognition model.

# %%
# Confusion Matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(labels, predicted_classes_test)
plt.figure(figsize=(12, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
# Randomly select and display some sample test images
import random

plt.figure(figsize=(12, 6))
sample_indices = random.sample(range(len(labels)), 9)
for i, idx in enumerate(sample_indices):
    plt.subplot(3, 3, i + 1)
    plt.imshow(X_test[idx])
    plt.title(f'True: {labels[idx]}\nPredicted: {predicted_classes_test[idx]}')
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
# Plot the learning rate schedule
learning_rates = [lr_schedule(epoch) for epoch in range(eps)]
plt.plot(range(eps), learning_rates)
plt.title('Learning Rate Schedule')
plt.xlabel('Epochs')
plt.ylabel('Learning Rate')
plt.show()

# %%
#Save the Trained Model
model.save('traffic_classifier.keras')
